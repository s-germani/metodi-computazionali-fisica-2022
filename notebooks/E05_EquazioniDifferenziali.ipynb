# %% [markdown]
# # Esercitazione su Equazioni Differenziali

# %% [markdown]
# ##  Filtro Passa Basso

# %% [markdown]
# Dato il circuito RC in figura:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Indicando con  $I$ la corrente eletrica che attraversa  la resistenza $R$ e il condensatore con capacità $C$ e carica $Q$ abbiamo:
#
# $$
# \begin{eqnarray}
# V_{in}-V_{out}  & = & IR\\
#  C V_{out} & = & Q \\
# \frac{dQ}{dt} & = & I \\
# \end{eqnarray}
# $$
#
# da cui possiamo ricavare l'equazione differenziale:
#
# $$
# \frac{d V_{out}}{dt} = \frac{1}{RC} (V_{in} - V_{out})
# $$

# %% [markdown]
# Scrivere uno script python che:
# * Risolva l'equazione differenziale per $V_{out}$ dato $V_{in}$.
# * Definisca $V_{in}$ per il tempo $t \in [0-10]$ tale che:
# $$
# V_{in}(t) =
# \begin{cases}
# +1   \;\; [t] \; pari \\
# -1 \;\;  [t] \; dispari\\
# \end{cases}
# $$
# * Produca un grafico di $V_{in}$ e $V_{out}$ per:
# $$
# \begin{cases}
# RC = 1    \\
# RC = 0.1  \\
# RC = 0.01 \\
# \end{cases}
# $$
# con la condizione iniziale $V_{out}(0) = 0$.
# * Salvi i risultati ($t, V_{in}(t), V_{out}(t)$) in unfile CSV. I risultati per $V_{out}(t)$ per i tre valori di RC vanno salvati nello stesso file.
# * OPZIONALE ripetere i passi precendenti con in potenziake $V_{in}$ diverso.

# %% [markdown]
# ## Pendolo

# %% [markdown]
# <div>
# <img src="attachment:image.png" width=150>
# </div>

# %% [markdown]
# L'equazione del moto del pendolo semplice con massa $m$ e lunghezza del filo $l$ :
#
# $$
# ml \frac{d^2 \theta}{d t^2} = -mg \sin(\theta)
# $$
#
#
# $$
#  \frac{d^2 \theta}{d t^2} = -\frac{g}{l} \sin(\theta)
# $$
#
#
# Definendo:
# $$
# \frac{d \theta}{d t} = \omega
# $$
#
# Il moto del pendolo può essere descritto dalle due equazioni:
#
# $$
# \begin{cases}
# \begin{eqnarray}
# \frac{d \theta}{d t} &  = & \omega \\
#  \frac{d \omega}{d t}&  =  & -\frac{g}{l} \sin(\theta) \\
# \end{eqnarray}
# \end{cases}
# $$
#
# Pe risolvere le equazioni del moto numericamente combiniamo le variabili $\theta$ e $\omega$ nel vettore ${\bf r}(\theta, \omega)$.

# %% [markdown]
# 1. Definire una funzione pe le equazioni differeziali che descrivon il moto del pendolo semplice
# 2. Risolvere l'equzione differnziale attraverso `scipy.integrate.odeint` con le seguenti caratteristiche:
#     1. $l = 0.5 \;m$
#     2. $\theta_0 = 45^{\circ}$
#     3. $\omega_0 = 0$
# 3. Produrre il grafico di $\theta$ in funzione del tempo
# 4. Risolvere l'eqauazione per diverse condizioni iniziali:
#     1. $l = 1 \;m$,    $\theta_0 = 45^{\circ}$
#     2. $l = 0.5 \;m$,  $\theta_0 = 30^{\circ}$
# 5. Confrontare in maniera appropriata il grafico di $\theta$ vs $t$ per le diverse condizioni iniziali

# %% [markdown]
# ## Oscillatore Anarmonico

# %% [markdown]
# Data  la seguente  equazione del moto per un oscillatore anarmonico:
#
# $$
# \frac{d^2 x}{dt^2} = - \omega^2 x^3
# $$
#
# 1. Risolvere l'equazione per diverse condizioni iniziali;
# 2. Confrontare graficamente i risultati;
